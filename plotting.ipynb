# %%
import plotting_utils as pl
import numpy as np

# %%
general_directory = "/hpcwork/zu992399/model-agnostic-model-selection/"
plotting_directory = "plots/"

signals = np.array([0, 50, 100, 150, 200, 250, 300, 400, 500, 600, 700, 800, 900, 1000])
signals_plot = np.array([0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])
signals_plot = np.array([0, 200, 400, 600, 800, 1000])

# %%
mode = "IAD"
rotated = False
pl.plot_feature_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, ylim=40, plot_default=False, feature_sets=["baseline", "DeltaR", "extended1", "extended2", "extended3"])
pl.plot_feature_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, ylim=40, plot_default=False, feature_sets=["baseline", "DeltaR", "extended1", "extended2", "extended3"], metric="val_loss")

# %%
mode = "IAD"
rotated = True
pl.plot_feature_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, ylim=40, plot_default=False, feature_sets=["baseline", "DeltaR", "extended1", "extended2", "extended3"], loc="upper right")
pl.plot_feature_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, ylim=40, plot_default=False, feature_sets=["baseline", "DeltaR", "extended1", "extended2", "extended3"], metric="val_loss", loc="upper right")

# %%
mode = "cwola"
rotated = False
pl.plot_feature_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, ylim=40, plot_default=False, feature_sets=["baseline", "DeltaR", "extended1", "extended2", "extended3"])
pl.plot_feature_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, ylim=40, plot_default=False, feature_sets=["baseline", "extended1", "extended2", "extended3"])
pl.plot_feature_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, ylim=40, plot_default=False, feature_sets=["baseline", "extended1", "extended2", "extended3"], metric="val_loss")
#pl.plot_rotation_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)

# %%
mode = "IAD"
rotated = False
pl.plot_default_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)
pl.plot_epoch_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, signal_specific=400, run=5)
pl.plot_optimized_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)
pl.plot_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)
pl.plot_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, metric="val_loss")
#pl.plot_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, metric="val_loss")

# %%
mode = "IAD"
rotated = True
pl.plot_default_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)
pl.plot_optimized_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)
pl.plot_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated,)
pl.plot_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, metric="val_loss")
"""pl.plot_default_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)
pl.plot_optimized_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, loc="upper right")
pl.plot_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)
pl.plot_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, metric="val_loss")"""
# Out:
# 'pl.plot_default_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)\npl.plot_optimized_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, loc="upper right")\npl.plot_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)\npl.plot_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, metric="val_loss")'

# %%
mode = "cwola"
rotated = False
pl.plot_epoch_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, signal_specific=800, run=5)
pl.plot_optimized_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)
pl.plot_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated )
pl.plot_selection(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, metric="val_loss")

# %%
mode = "cathode"
rotated = False
pl.plot_default_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)
