# %%
import plotting_utils as pl
import numpy as np

# %%
general_directory = "/hpcwork/zu992399/model-agnostic-model-selection/"
plotting_directory = "plots/"

signals = np.array([0, 50, 100, 150, 200, 250, 300, 400, 500, 600, 700, 800, 900, 1000])
signals_plot = np.array([0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])

# %%
mode = "IAD"
rotated = False
pl.plot_default_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)
pl.plot_optimized_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, classifiers=["NN", "HGB"])

# %%
mode = "IAD"
rotated = True
pl.plot_default_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)
pl.plot_optimized_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, classifiers=["HGB", "NN"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 rotated = True
#       3 pl.plot_default_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)
# ----> 4 pl.plot_optimized_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated, classifiers=["HGB", "NN"])
#
# File /rwthfs/rz/cluster/home/zu992399/PhD/model-agnostic-model-selection/plotting_utils.py:170, in plot_optimized_runs(mode, signals, signals_plot, gen_direc, plotting_directory, rotated, metrics, classifiers)
#     168 		folder = gen_direc+c+"/optimized_hp/"+mode+"/"+m+"/"
#     169 	for j,s in enumerate(signals):
# --> 170 		sic[j], sic_low[j], sic_upp[j] = read_ROC_SIC_1D(roc_name, points, folder + "Nsig_"+str(s)+"/")
#     171 	plot_sic(ax[i], sic[:,index], sic_low[:,index], sic_upp[:,index], signals, metric_colors[m], "Optimized on "+metric_names[m])
#     172 plot_end_1D_multiple(ax[i], signals_plot,title=c)
#
# File /rwthfs/rz/cluster/home/zu992399/PhD/model-agnostic-model-selection/plotting_utils.py:54, in read_ROC_SIC_1D(path, points, folder, N_runs, start_runs)
#      53 def read_ROC_SIC_1D(path, points, folder, N_runs=10, start_runs=0):
# ---> 54 	fpr=np.load(folder+"fpr_"+path+".npy")[start_runs:start_runs+N_runs]
#      55 	#print(fpr.shape)
#      56 	tpr=np.load(folder+"tpr_"+path+".npy")[start_runs:start_runs+N_runs]
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/npyio.py:407, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     405     own_fid = False
#     406 else:
# --> 407     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     408     own_fid = True
#     410 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/hpcwork/zu992399/model-agnostic-model-selection/NN/optimized_hp/IAD_rotated/max_SIC/Nsig_0/fpr_max_sic.npy'

# %%
mode = "cathode"
rotated = False
pl.plot_default_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)

# %%
mode = "cwola"
rotated = False
pl.plot_default_runs(mode, signals, signals_plot, general_directory, plotting_directory, rotated=rotated)
